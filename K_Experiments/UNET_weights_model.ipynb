# %%
import os
import cv2
import time
import shutil
import random
import inspect
#import imageio as im
import numpy as np
import mahotas as mh
from PIL import Image
from tabulate import tabulate
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import keras
from keras_unet.models import custom_unet
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xd
# Could not import submodules (exact error was: numpy.core.multiarray failed to import).
#
# There are many reasons for this error the most common one is that you have
# either not built the packages or have built (using `python setup.py build`) or
# installed them (using `python setup.py install`) and then proceeded to test
# mahotas-imread **without changing the current directory**.
#
# Try installing and then changing to another directory before importing mahotas.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xd
# 2023-04-08 17:50:26.944035: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
experiment = "test3"

# %%
# original directory path and working directory path for images
data = "/raid/mpsych/RISTERLAB/fly_segmentation_experiments/data_dir/raw_files"
working_dir = "/raid/mpsych/RISTERLAB/fly_segmentation_experiments/data_dir"
######################################################################################################
#experiment = "test3" 
######################################################################################################
real = f"{working_dir}/{experiment}/real_images"
#########################################################################################################
machine = f"{working_dir}/{experiment}/pre_processing/machine"
npy = f"{working_dir}/{experiment}/pre_processing/npy"

directories = {
    "normalized": f"{working_dir}/{experiment}/normalized_images",
    "cropped": f"{working_dir}/{experiment}/cropped_images",
    "npy": f"{working_dir}/{experiment}/pre_processing/npy1",
    "originals": f"{working_dir}/{experiment}/pre_processing/originals",
    "masks": f"{working_dir}/{experiment}/pre_processing/masks",
    "test": f"{working_dir}/{experiment}/pre_processing/test",
    "s": f"{working_dir}/{experiment}/S",
    "crop_original": f"{working_dir}/{experiment}/pre_processing/crop_originals",
    "crop_masks": f"{working_dir}/{experiment}/pre_processing/crop_masks",
    "op": f"{working_dir}/{experiment}/post_processing/original_prediction",
    "pp": f"{working_dir}/{experiment}/post_processing/processed_prediction"
    
}

# %%
npy = f"{working_dir}/{experiment}/pre_processing/npy1"
new_unet = f"{working_dir}/{experiment}/unet_prediction_save"

# %%
import keras
from keras_unet.models import custom_unet

# %%
def dataset1():
    imagedata = np.load(os.path.join(npy, 'poo.npz'))
    labeldata = np.load(os.path.join(npy, 'pom.npz'))
    return imagedata,labeldata

# %%
def dataset2():
    imagedata = np.load(os.path.join(npy, 'original.npz'))
    labeldata = np.load(os.path.join(npy, 'mask.npz'))
    return imagedata,labeldata

# %%
# imagedata = np.load(os.path.join(npy, 'original.npz'))
# labeldata = np.load(os.path.join(npy, 'mask.npz'))

# %%
imagedata = np.load(os.path.join(npy, 'poo.npz'))
labeldata = np.load(os.path.join(npy, 'pom.npz'))

# %%
images_file = imagedata['data']
images_name = imagedata['names']

# %%
len (images_name)
# Out:
# 38052

# %%
labels_file = labeldata['data']
labels_name = labeldata['names']

# %%
images = images_file
labels = labels_file

# %%
images.shape
# Out:
# (38052, 512, 512)

# %%
labels.shape
# Out:
# (38052, 512, 512)

# %%
 # full dataset does not have the last channel
images = images.reshape(images.shape[0],images.shape[1],images.shape[2],1)
labels = labels.reshape(labels.shape[0],labels.shape[1],labels.shape[2],1)
#test = test.reshape(test.shape[0],test.shape[1],test.shape[2],1)

# %%
images.shape
# Out:
# (38052, 512, 512, 1)

# %%
labels.shape
# Out:
# (38052, 512, 512, 1)

# %%
p = np.random.permutation(len(images))

# %%
images = images[p]
labels = labels[p]

# %%
labels = labels.astype(np.float64)

# %%
# images = images.astype(np.float64)
# for i in range(images.shape[0]):
#     images[i] = (images[i] - images[i].min()) / (images[i].max() - images[i].min()) # normalize individually

# %%
# from sklearn.model_selection import train_test_split

# # Split the data into training and testing sets with a ratio of 85:15
# X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.15)

# # Further split the training set into training and validation sets with a ratio of 82:18
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1765)

# %%
X_train = images[0:1350]
y_train = labels[0:1350]
X_val = images[1351:1570]
y_val = labels[1351:1570]
X_test = images[1571:]
y_test = labels[1571:]

# %%
y_train.shape
# Out:
# (1350, 512, 512, 1)

# %%
X_train.shape
# Out:
# (1350, 512, 512, 1)

# %%
from keras import regularizers
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras_unet.utils import plot_segm_history, plot_imgs
import cv2
from PIL import Image
from skimage.filters import threshold_otsu
from keras.preprocessing.image import ImageDataGenerator

import keras.optimizers
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance
import keras.optimizers
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance

# %%
model = custom_unet(
                    input_shape=(512, 512, 1),
                    use_batch_norm=False,
                    num_classes=1,
                    filters=32,
                    dropout=0.5,
                    output_activation='sigmoid')

# %%
opt = keras.optimizer_v1.Adam(lr=0.01)

# %%
model.compile(optimizer = 'Adam',    
              loss='binary_crossentropy', 
              metrics=[iou, iou_thresholded])

# %%
path = '/raid/mpsych/RISTERLAB/kiran/flyem/K_Experiments/models/Unet'

# %%
# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
# Training with early stopping
history = model.fit(X_train,
                    y_train,
                    batch_size=5,
                    epochs=100,
                    validation_data=(X_val, y_val),
                    callbacks=[early_stopping])


y_pred = model.predict(X_test)

for i in range(15):
    # Apply thresholding
    threshold = 0.2
    y_pred_binary = (y_pred [i]> threshold).astype(np.uint8)
    binary_mask = y_pred_binary
    z = images_name[i]
    plt.imshow(binary_mask)
    plt.show()

# save the updated weights of the new model
model.save_weights(f'{path}/new_Uidmodel1.h5')
print (f'saved model : new_Umodel1.h5')
threshold = 0.2
y_pred_binary = (y_pred > threshold).astype(np.uint8)
plot_segm_history(history)   
plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=10)
    # Convert the binary_mask variable to a 2D array
  #  binary_mask_2d = binary_mask.squeeze()
    # Convert the binary_mask variable to uint8 format
#    binary_mask_uint8 = (binary_mask_2d * 255).astype(np.uint8)
   # save_path = os.path.join(new_unet, z) 
   # binary_mask_new = np.array(binary_mask_uint8)
    #mh.imsave(save_path, binary_mask_new)
    
 # Plotting results
# Apply thresholding


# history.history.keys()
# metrics = list(history.history.keys())
# plot_segm_history(history, metrics=metrics)   
# plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=30)

# #print ('completed iteration number',k,'The value of al is ',al)
print ('#############################')
print()
print()
print()
# Out:
# 2023-04-08 17:52:06.026117: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-04-08 17:52:06.045177: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245645000 Hz
# Epoch 1/100
# 2023-04-08 17:52:07.265953: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-04-08 17:52:07.888298: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8201
# 2023-04-08 17:52:08.543891: W tensorflow/stream_executor/gpu/asm_compiler.cc:191] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.0
# 2023-04-08 17:52:08.543919: W tensorflow/stream_executor/gpu/asm_compiler.cc:194] Used ptxas at ptxas
# 2023-04-08 17:52:08.543984: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-04-08 17:52:08.589227: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-04-08 17:52:09.297001: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 135/135 [==============================] - 23s 113ms/step - loss: nan - iou: nan - iou_thresholded: 3.7931 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 2/100
# 135/135 [==============================] - 13s 97ms/step - loss: nan - iou: nan - iou_thresholded: 1.3744e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 3/100
# 135/135 [==============================] - 13s 97ms/step - loss: nan - iou: nan - iou_thresholded: 1.3738e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 4/100
# 135/135 [==============================] - 13s 98ms/step - loss: nan - iou: nan - iou_thresholded: 1.3762e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 5/100
# 135/135 [==============================] - 13s 97ms/step - loss: nan - iou: nan - iou_thresholded: 1.3767e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 6/100
# 135/135 [==============================] - 13s 96ms/step - loss: nan - iou: nan - iou_thresholded: 1.3768e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 7/100
# 135/135 [==============================] - 13s 97ms/step - loss: nan - iou: nan - iou_thresholded: 1.3803e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 8/100
# 135/135 [==============================] - 13s 97ms/step - loss: nan - iou: nan - iou_thresholded: 1.3755e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 9/100
# 135/135 [==============================] - 13s 97ms/step - loss: nan - iou: nan - iou_thresholded: 1.3797e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# Epoch 10/100
# 135/135 [==============================] - 13s 98ms/step - loss: nan - iou: nan - iou_thresholded: 1.3808e-08 - val_loss: nan - val_iou: nan - val_iou_thresholded: 1.4194e-08
# 2023-04-08 17:57:01.287018: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.00GiB (rounded to 2147483648)requested by op model_1/concatenate_7/concat
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-04-08 17:57:01.287855: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2023-04-08 17:57:01.287928: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 90, Chunks in use: 89. 22.5KiB allocated for chunks. 22.2KiB in use in bin. 6.3KiB client-requested in use in bin.
# 2023-04-08 17:57:01.288004: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 17, Chunks in use: 15. 8.8KiB allocated for chunks. 7.5KiB in use in bin. 7.5KiB client-requested in use in bin.
# 2023-04-08 17:57:01.288097: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 25, Chunks in use: 19. 28.2KiB allocated for chunks. 20.2KiB in use in bin. 19.4KiB client-requested in use in bin.
# 2023-04-08 17:57:01.288198: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 9, Chunks in use: 6. 20.0KiB allocated for chunks. 12.0KiB in use in bin. 12.0KiB client-requested in use in bin.
# 2023-04-08 17:57:01.288298: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-08 17:57:01.288393: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-08 17:57:01.288491: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-08 17:57:01.288546: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 10, Chunks in use: 9. 374.8KiB allocated for chunks. 338.8KiB in use in bin. 312.0KiB client-requested in use in bin.
# 2023-04-08 17:57:01.288600: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 7, Chunks in use: 6. 579.0KiB allocated for chunks. 467.8KiB in use in bin. 432.0KiB client-requested in use in bin.
# 2023-04-08 17:57:01.288651: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 9, Chunks in use: 9. 1.31MiB allocated for chunks. 1.31MiB in use in bin. 1.22MiB client-requested in use in bin.
# 2023-04-08 17:57:01.288700: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 8, Chunks in use: 6. 2.50MiB allocated for chunks. 1.69MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2023-04-08 17:57:01.288750: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 9, Chunks in use: 9. 5.25MiB allocated for chunks. 5.25MiB in use in bin. 4.88MiB client-requested in use in bin.
# 2023-04-08 17:57:01.288800: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 8, Chunks in use: 6. 9.78MiB allocated for chunks. 6.75MiB in use in bin. 6.75MiB client-requested in use in bin.
# 2023-04-08 17:57:01.288854: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 9, Chunks in use: 9. 20.00MiB allocated for chunks. 20.00MiB in use in bin. 19.50MiB client-requested in use in bin.
# 2023-04-08 17:57:01.288904: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 9, Chunks in use: 6. 43.62MiB allocated for chunks. 27.00MiB in use in bin. 27.00MiB client-requested in use in bin.
# 2023-04-08 17:57:01.288955: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 9, Chunks in use: 7. 88.50MiB allocated for chunks. 67.00MiB in use in bin. 67.00MiB client-requested in use in bin.
# 2023-04-08 17:57:01.289005: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-08 17:57:01.289055: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 1003, Chunks in use: 1003. 31.36GiB allocated for chunks. 31.36GiB in use in bin. 31.34GiB client-requested in use in bin.
# 2023-04-08 17:57:01.289119: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-08 17:57:01.289171: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-08 17:57:01.289227: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 5, Chunks in use: 2. 6.00GiB allocated for chunks. 2.00GiB in use in bin. 2.00GiB client-requested in use in bin.
# 2023-04-08 17:57:01.289282: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 2.00GiB was 256.00MiB, Chunk State:
# 2023-04-08 17:57:01.289340: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 1.00GiB | Requested Size: 1.00GiB | in_use: 0 | bin_num: 20, prev:   Size: 1.00GiB | Requested Size: 1.00GiB | in_use: 1 | bin_num: -1, for: model_1/conv2d_20/Relu, stepid: 15269922707495063983, last_action: 100056485642129, next:   Size: 1.00GiB | Requested Size: 1.00GiB | in_use: 1 | bin_num: -1, for: model_1/conv2d_transpose_7/conv2d_transpose, stepid: 15269922707495063983, last_action: 100056485642258, for: UNUSED, stepid: 15269922707495063983, last_action: 100056485642260
# 2023-04-08 17:57:01.289403: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 1.03GiB | Requested Size: 512.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 32.00MiB | Requested Size: 32.00MiB | in_use: 1 | bin_num: -1, for: model_1/conv2d_37/Conv2D, stepid: 9894452489973135580, last_action: 100056485642116, next:   Size: 1.00GiB | Requested Size: 1.00GiB | in_use: 1 | bin_num: -1, for: model_1/conv2d_20/Relu, stepid: 15269922707495063983, last_action: 100056485642129, for: UNUSED, stepid: 15269922707495063983, last_action: 100056485642263
# 2023-04-08 17:57:01.289466: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 1.97GiB | Requested Size: 1.50GiB | in_use: 0 | bin_num: 20, prev:   Size: 1.00GiB | Requested Size: 1.00GiB | in_use: 1 | bin_num: -1, for: model_1/conv2d_transpose_7/conv2d_transpose, stepid: 15269922707495063983, last_action: 100056485642258, next:   Size: 32.00MiB | Requested Size: 32.00MiB | in_use: 1 | bin_num: -1, for: model_1/conv2d_37/Conv2D, stepid: 17933072755382380555, last_action: 100056485621252, for: UNUSED, stepid: 15269922707495063983, last_action: 100056485642261
# 2023-04-08 17:57:01.289519: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 40291729408
# 2023-04-08 17:57:01.289567: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8000000 of size 1280 by op ScratchBuffer action_count 100056484444709 step 0 next 1
# 2023-04-08 17:57:01.289618: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8000500 of size 256 by op Fill action_count 100056484444717 step 0 next 7
# 2023-04-08 17:57:01.289667: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8000600 of size 256 by op Const action_count 100056485478311 step 0 next 8
# 2023-04-08 17:57:01.289717: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8000700 of size 256 by op Mul action_count 100056484444720 step 0 next 10
# 2023-04-08 17:57:01.289766: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8000800 of size 512 by op UNUSED action_count 100056485478266 step 0 next 2
# 2023-04-08 17:57:01.289814: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8000a00 of size 256 by op Mul action_count 100056484444711 step 0 next 3
# 2023-04-08 17:57:01.289861: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8000b00 of size 256 by op Mul action_count 100056484444733 step 0 next 16
# 2023-04-08 17:57:01.289914: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8000c00 of size 1024 by op UNUSED action_count 100056485478268 step 0 next 4
# 2023-04-08 17:57:01.289962: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8001000 of size 256 by op Add action_count 100056484444713 step 0 next 5
# 2023-04-08 17:57:01.290008: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8001100 of size 1280 by op UNUSED action_count 100056485642127 step 15269922707495063983 next 6
# 2023-04-08 17:57:01.290057: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8001600 of size 256 by op Mul action_count 100056484444746 step 0 next 22
# 2023-04-08 17:57:01.290103: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8001700 of size 1536 by op UNUSED action_count 100056485478270 step 0 next 27
# 2023-04-08 17:57:01.290149: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8001d00 of size 256 by op Mul action_count 100056484444759 step 0 next 29
# 2023-04-08 17:57:01.290196: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8001e00 of size 3072 by op UNUSED action_count 100056485478272 step 0 next 34
# 2023-04-08 17:57:01.290242: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8002a00 of size 256 by op Mul action_count 100056484444772 step 0 next 36
# 2023-04-08 17:57:01.290287: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8002b00 of size 2048 by op UNUSED action_count 100056485478290 step 0 next 35
# 2023-04-08 17:57:01.290333: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8003300 of size 256 by op Sub action_count 100056484444779 step 0 next 40
# 2023-04-08 17:57:01.290379: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8003400 of size 256 by op Sub action_count 100056484444780 step 0 next 41
# 2023-04-08 17:57:01.290425: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8003500 of size 3072 by op UNUSED action_count 100056485478276 step 0 next 47
# 2023-04-08 17:57:01.290473: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8004100 of size 256 by op Sub action_count 100056484444801 step 0 next 49
# 2023-04-08 17:57:01.290521: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8004200 of size 256 by op Sub action_count 100056484444802 step 0 next 50
# 2023-04-08 17:57:01.290569: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8004300 of size 1536 by op UNUSED action_count 100056485478274 step 0 next 55
# 2023-04-08 17:57:01.290616: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8004900 of size 256 by op Sub action_count 100056484444823 step 0 next 57
# 2023-04-08 17:57:01.290662: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8004a00 of size 256 by op Sub action_count 100056484444824 step 0 next 58
# 2023-04-08 17:57:01.290708: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8004b00 of size 768 by op UNUSED action_count 100056485478296 step 0 next 63
# 2023-04-08 17:57:01.290759: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c8004e00 of size 59392 by op Add action_count 100056484445013 step 0 next 11
# 2023-04-08 17:57:01.290807: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c8013600 of size 36864 by op UNUSED action_count 100056485642262 step 15269922707495063983 next 12
# 2023-04-08 17:57:01.290854: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c801c600 of size 256 by op Sub action_count 100056484444845 step 0 next 64
# 2023-04-08 17:57:01.290903: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c801c700 of size 256 by op Sub action_count 100056484444846 step 0 next 65
# 2023-04-08 17:57:01.290950: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f39c801c800 of size 1024 by op UNUSED action_count 100056485478306 step 0 next 72
# 2023-04-08 17:57:01.290996: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f39c
W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at concat_op.cc:158 : Resource exhausted: OOM when allocating tensor with shape[32,64,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_1008204/4042140265.py in <module>
#      10
#      11
# ---> 12 y_pred = model.predict(X_test)
#      13
#      14 for i in range(15):
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1725           for step in data_handler.steps():
#    1726             callbacks.on_predict_batch_begin(step)
# -> 1727             tmp_batch_outputs = self.predict_function(iterator)
#    1728             if data_handler.should_sync:
#    1729               context.async_wait()
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     922       # In this case we have not created variables on the first call. So we can
#     923       # run the first trace but we should fail if variables are created.
# --> 924       results = self._stateful_fn(*args, **kwds)
#     925       if self._created_variables:
#     926         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~/miniconda3/envs/O/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[32,64,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node model_1/concatenate_7/concat (defined at tmp/ipykernel_1008204/4042140265.py:12) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_predict_function_9120]
#
# Function call stack:
# predict_function

# %%
# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
# Training with early stopping
history = model.fit(X_train,
                    y_train,
                    batch_size=60,
                    epochs=100,
                    validation_data=(X_val, y_val),
                    callbacks=[early_stopping])


y_pred = model.predict(X_test)

for i in range(15):
    # Apply thresholding
    threshold = 0.2
    y_pred_binary = (y_pred > threshold).astype(np.uint8)
    binary_mask = y_pred_binary[i]
    z = images_name[i]
    # Convert the binary_mask variable to a 2D array
    binary_mask_2d = binary_mask.squeeze()
    # Convert the binary_mask variable to uint8 format
    binary_mask_uint8 = (binary_mask_2d * 255).astype(np.uint8)
    save_path = os.path.join(new_unet, z) 
    binary_mask_new = np.array(binary_mask_uint8)
    mh.imsave(save_path, binary_mask_new)
    
# save the updated weights of the new model
new_model.save_weights(f'{path}/new_Umodel{bl}.h5')
print (f'saved model : new_Umodel{bl}.h5')
threshold = 0.2
y_pred_binary = (y_pred > threshold).astype(np.uint8)
plot_segm_history(history)   
plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=10)

# history.history.keys()
# metrics = list(history.history.keys())
# plot_segm_history(history, metrics=metrics)   
# plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=30)

# #print ('completed iteration number',k,'The value of al is ',al)
print ('#############################')
print()
print()
print()
# Out:
# Epoch 1/100
# 22/22 [==============================] - 17s 724ms/step - loss: 4.2619 - iou: 0.0594 - iou_thresholded: 0.0585 - val_loss: 0.6628 - val_iou: 0.0910 - val_iou_thresholded: 0.0877
# Epoch 2/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.6613 - iou: 0.0777 - iou_thresholded: 0.0484 - val_loss: 0.4254 - val_iou: 0.0826 - val_iou_thresholded: 0.0013
# Epoch 3/100
# 22/22 [==============================] - 15s 699ms/step - loss: 0.4408 - iou: 0.0825 - iou_thresholded: 0.0171 - val_loss: 0.4356 - val_iou: 0.1020 - val_iou_thresholded: 1.0536e-04
# Epoch 4/100
# 22/22 [==============================] - 15s 697ms/step - loss: 0.3959 - iou: 0.0863 - iou_thresholded: 0.0044 - val_loss: 0.4614 - val_iou: 0.1073 - val_iou_thresholded: 4.9538e-05
# Epoch 5/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.3664 - iou: 0.0971 - iou_thresholded: 0.0020 - val_loss: 0.4123 - val_iou: 0.1145 - val_iou_thresholded: 4.9130e-05
# Epoch 6/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.3506 - iou: 0.0982 - iou_thresholded: 0.0011 - val_loss: 0.3609 - val_iou: 0.1205 - val_iou_thresholded: 4.4439e-05
# Epoch 7/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.3441 - iou: 0.1041 - iou_thresholded: 0.0012 - val_loss: 0.3465 - val_iou: 0.1211 - val_iou_thresholded: 2.9706e-05
# Epoch 8/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.3293 - iou: 0.1072 - iou_thresholded: 7.7757e-04 - val_loss: 0.3236 - val_iou: 0.1269 - val_iou_thresholded: 9.2846e-06
# Epoch 9/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.3276 - iou: 0.1106 - iou_thresholded: 5.4353e-04 - val_loss: 0.3192 - val_iou: 0.1288 - val_iou_thresholded: 1.5811e-06
# Epoch 10/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.3046 - iou: 0.1212 - iou_thresholded: 5.3897e-04 - val_loss: 0.3247 - val_iou: 0.1368 - val_iou_thresholded: 2.2696e-06
# Epoch 11/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.2945 - iou: 0.1375 - iou_thresholded: 9.9558e-04 - val_loss: 0.3073 - val_iou: 0.1415 - val_iou_thresholded: 6.8048e-07
# Epoch 12/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.2660 - iou: 0.1571 - iou_thresholded: 5.4818e-04 - val_loss: 0.3452 - val_iou: 0.1309 - val_iou_thresholded: 1.2629e-06
# Epoch 13/100
# 22/22 [==============================] - 16s 708ms/step - loss: 0.2615 - iou: 0.1653 - iou_thresholded: 4.6502e-04 - val_loss: 0.2770 - val_iou: 0.1612 - val_iou_thresholded: 1.1444e-06
# Epoch 14/100
# 22/22 [==============================] - 15s 706ms/step - loss: 0.2441 - iou: 0.1809 - iou_thresholded: 5.4906e-04 - val_loss: 0.2900 - val_iou: 0.1585 - val_iou_thresholded: 1.2569e-06
# Epoch 15/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.2301 - iou: 0.1988 - iou_thresholded: 0.0012 - val_loss: 0.2805 - val_iou: 0.1685 - val_iou_thresholded: 9.1152e-07
# Epoch 16/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.2195 - iou: 0.2125 - iou_thresholded: 8.5200e-04 - val_loss: 0.3125 - val_iou: 0.1603 - val_iou_thresholded: 9.1153e-07
# Epoch 17/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.2054 - iou: 0.2340 - iou_thresholded: 7.2588e-04 - val_loss: 0.2703 - val_iou: 0.1880 - val_iou_thresholded: 1.1384e-06
# Epoch 18/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.1911 - iou: 0.2569 - iou_thresholded: 8.0885e-04 - val_loss: 0.2321 - val_iou: 0.2183 - val_iou_thresholded: 2.6165e-06
# Epoch 19/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.1874 - iou: 0.2663 - iou_thresholded: 0.0013 - val_loss: 0.2023 - val_iou: 0.2471 - val_iou_thresholded: 9.5682e-06
# Epoch 20/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.1804 - iou: 0.2810 - iou_thresholded: 6.3978e-04 - val_loss: 0.2128 - val_iou: 0.2428 - val_iou_thresholded: 3.2742e-06
# Epoch 21/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.1693 - iou: 0.2996 - iou_thresholded: 7.0998e-04 - val_loss: 0.1759 - val_iou: 0.2812 - val_iou_thresholded: 1.4890e-05
# Epoch 22/100
# 22/22 [==============================] - 16s 711ms/step - loss: 0.1671 - iou: 0.3052 - iou_thresholded: 5.8295e-04 - val_loss: 0.1853 - val_iou: 0.2754 - val_iou_thresholded: 7.4005e-06
# Epoch 23/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.1635 - iou: 0.3127 - iou_thresholded: 6.6426e-04 - val_loss: 0.1619 - val_iou: 0.3054 - val_iou_thresholded: 3.3715e-05
# Epoch 24/100
# 22/22 [==============================] - 16s 713ms/step - loss: 0.1669 - iou: 0.3106 - iou_thresholded: 5.7600e-04 - val_loss: 0.1631 - val_iou: 0.3049 - val_iou_thresholded: 1.8646e-05
# Epoch 25/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.1512 - iou: 0.3356 - iou_thresholded: 0.0874 - val_loss: 0.1530 - val_iou: 0.3222 - val_iou_thresholded: 0.6352
# Epoch 26/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.1450 - iou: 0.3467 - iou_thresholded: 0.6306 - val_loss: 0.1999 - val_iou: 0.2680 - val_iou_thresholded: 0.5117
# Epoch 27/100
# 22/22 [==============================] - 15s 705ms/step - loss: 0.1448 - iou: 0.3502 - iou_thresholded: 0.6368 - val_loss: 0.1426 - val_iou: 0.3416 - val_iou_thresholded: 0.6673
# Epoch 28/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.1376 - iou: 0.3626 - iou_thresholded: 0.6535 - val_loss: 0.1570 - val_iou: 0.3215 - val_iou_thresholded: 0.6223
# Epoch 29/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.1310 - iou: 0.3772 - iou_thresholded: 0.6784 - val_loss: 0.1533 - val_iou: 0.3288 - val_iou_thresholded: 0.6370
# Epoch 30/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.1291 - iou: 0.3801 - iou_thresholded: 0.6782 - val_loss: 0.1416 - val_iou: 0.3494 - val_iou_thresholded: 0.6615
# Epoch 31/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.1269 - iou: 0.3877 - iou_thresholded: 0.6881 - val_loss: 0.1303 - val_iou: 0.3721 - val_iou_thresholded: 0.6878
# Epoch 32/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.1278 - iou: 0.3882 - iou_thresholded: 0.6861 - val_loss: 0.1322 - val_iou: 0.3690 - val_iou_thresholded: 0.6828
# Epoch 33/100
# 22/22 [==============================] - 16s 717ms/step - loss: 0.1246 - iou: 0.3948 - iou_thresholded: 0.6909 - val_loss: 0.1214 - val_iou: 0.3926 - val_iou_thresholded: 0.7172
# Epoch 34/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.1205 - iou: 0.4036 - iou_thresholded: 0.7009 - val_loss: 0.1786 - val_iou: 0.3044 - val_iou_thresholded: 0.5700
# Epoch 35/100
# 22/22 [==============================] - 16s 713ms/step - loss: 0.1255 - iou: 0.3966 - iou_thresholded: 0.6861 - val_loss: 0.1462 - val_iou: 0.3500 - val_iou_thresholded: 0.6455
# Epoch 36/100
# 22/22 [==============================] - 15s 701ms/step - loss: 0.1183 - iou: 0.4107 - iou_thresholded: 0.7056 - val_loss: 0.1579 - val_iou: 0.3357 - val_iou_thresholded: 0.6118
# Epoch 37/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.1176 - iou: 0.4162 - iou_thresholded: 0.7155 - val_loss: 0.1399 - val_iou: 0.3646 - val_iou_thresholded: 0.6594
# Epoch 38/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.1155 - iou: 0.4218 - iou_thresholded: 0.7185 - val_loss: 0.1118 - val_iou: 0.4222 - val_iou_thresholded: 0.7366
# Epoch 39/100
# 22/22 [==============================] - 16s 707ms/step - loss: 0.1172 - iou: 0.4189 - iou_thresholded: 0.7070 - val_loss: 0.1177 - val_iou: 0.4078 - val_iou_thresholded: 0.7308
# Epoch 40/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.1125 - iou: 0.4310 - iou_thresholded: 0.7236 - val_loss: 0.1147 - val_iou: 0.4202 - val_iou_thresholded: 0.7249
# Epoch 41/100
# 22/22 [==============================] - 16s 707ms/step - loss: 0.1109 - iou: 0.4367 - iou_thresholded: 0.7309 - val_loss: 0.1278 - val_iou: 0.3934 - val_iou_thresholded: 0.6852
# Epoch 42/100
# 22/22 [==============================] - 16s 708ms/step - loss: 0.1093 - iou: 0.4424 - iou_thresholded: 0.7359 - val_loss: 0.1137 - val_iou: 0.4251 - val_iou_thresholded: 0.7249
# Epoch 43/100
# 22/22 [==============================] - 15s 705ms/step - loss: 0.1075 - iou: 0.4468 - iou_thresholded: 0.7374 - val_loss: 0.1105 - val_iou: 0.4313 - val_iou_thresholded: 0.7442
# Epoch 44/100
# 22/22 [==============================] - 16s 715ms/step - loss: 0.1051 - iou: 0.4537 - iou_thresholded: 0.7439 - val_loss: 0.1136 - val_iou: 0.4287 - val_iou_thresholded: 0.7268
# Epoch 45/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.1037 - iou: 0.4589 - iou_thresholded: 0.7476 - val_loss: 0.1442 - val_iou: 0.3741 - val_iou_thresholded: 0.6290
# Epoch 46/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.1084 - iou: 0.4488 - iou_thresholded: 0.7261 - val_loss: 0.1013 - val_iou: 0.4613 - val_iou_thresholded: 0.7644
# Epoch 47/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.1024 - iou: 0.4654 - iou_thresholded: 0.7496 - val_loss: 0.1155 - val_iou: 0.4295 - val_iou_thresholded: 0.7177
# Epoch 48/100
# 22/22 [==============================] - 16s 714ms/step - loss: 0.1006 - iou: 0.4699 - iou_thresholded: 0.7539 - val_loss: 0.1018 - val_iou: 0.4633 - val_iou_thresholded: 0.7617
# Epoch 49/100
# 22/22 [==============================] - 16s 712ms/step - loss: 0.1002 - iou: 0.4739 - iou_thresholded: 0.7545 - val_loss: 0.1373 - val_iou: 0.3888 - val_iou_thresholded: 0.6665
# Epoch 50/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.1215 - iou: 0.4341 - iou_thresholded: 0.6898 - val_loss: 0.1055 - val_iou: 0.4553 - val_iou_thresholded: 0.7352
# Epoch 51/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.1084 - iou: 0.4583 - iou_thresholded: 0.7222 - val_loss: 0.1211 - val_iou: 0.4196 - val_iou_thresholded: 0.7167
# Epoch 52/100
# 22/22 [==============================] - 16s 711ms/step - loss: 0.1002 - iou: 0.4776 - iou_thresholded: 0.7497 - val_loss: 0.1054 - val_iou: 0.4607 - val_iou_thresholded: 0.7435
# Epoch 53/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.0969 - iou: 0.4864 - iou_thresholded: 0.7612 - val_loss: 0.0981 - val_iou: 0.4777 - val_iou_thresholded: 0.7700
# Epoch 54/100
# 22/22 [==============================] - 16s 708ms/step - loss: 0.0955 - iou: 0.4918 - iou_thresholded: 0.7647 - val_loss: 0.1132 - val_iou: 0.4410 - val_iou_thresholded: 0.7340
# Epoch 55/100
# 22/22 [==============================] - 16s 707ms/step - loss: 0.0950 - iou: 0.4945 - iou_thresholded: 0.7676 - val_loss: 0.1004 - val_iou: 0.4733 - val_iou_thresholded: 0.7672
# Epoch 56/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.0929 - iou: 0.5013 - iou_thresholded: 0.7712 - val_loss: 0.0940 - val_iou: 0.4926 - val_iou_thresholded: 0.7853
# Epoch 57/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0921 - iou: 0.5061 - iou_thresholded: 0.7776 - val_loss: 0.0987 - val_iou: 0.4820 - val_iou_thresholded: 0.7690
# Epoch 58/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.0899 - iou: 0.5108 - iou_thresholded: 0.7783 - val_loss: 0.0955 - val_iou: 0.4914 - val_iou_thresholded: 0.7808
# Epoch 59/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0887 - iou: 0.5154 - iou_thresholded: 0.7833 - val_loss: 0.1015 - val_iou: 0.4799 - val_iou_thresholded: 0.7555
# Epoch 60/100
# 22/22 [==============================] - 15s 705ms/step - loss: 0.0890 - iou: 0.5192 - iou_thresholded: 0.7849 - val_loss: 0.1081 - val_iou: 0.4638 - val_iou_thresholded: 0.7404
# Epoch 61/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0873 - iou: 0.5250 - iou_thresholded: 0.7910 - val_loss: 0.0877 - val_iou: 0.5208 - val_iou_thresholded: 0.7970
# Epoch 62/100
# 22/22 [==============================] - 15s 705ms/step - loss: 0.0874 - iou: 0.5239 - iou_thresholded: 0.7832 - val_loss: 0.0897 - val_iou: 0.5127 - val_iou_thresholded: 0.7915
# Epoch 63/100
# 22/22 [==============================] - 16s 713ms/step - loss: 0.0871 - iou: 0.5281 - iou_thresholded: 0.7874 - val_loss: 0.1179 - val_iou: 0.4478 - val_iou_thresholded: 0.7091
# Epoch 64/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.0861 - iou: 0.5305 - iou_thresholded: 0.7885 - val_loss: 0.0938 - val_iou: 0.5061 - val_iou_thresholded: 0.7777
# Epoch 65/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.0839 - iou: 0.5393 - iou_thresholded: 0.7969 - val_loss: 0.0883 - val_iou: 0.5242 - val_iou_thresholded: 0.7916
# Epoch 66/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.0834 - iou: 0.5428 - iou_thresholded: 0.7982 - val_loss: 0.0842 - val_iou: 0.5367 - val_iou_thresholded: 0.8058
# Epoch 67/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0822 - iou: 0.5467 - iou_thresholded: 0.7997 - val_loss: 0.1245 - val_iou: 0.4396 - val_iou_thresholded: 0.6955
# Epoch 68/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.0875 - iou: 0.5329 - iou_thresholded: 0.7776 - val_loss: 0.0857 - val_iou: 0.5415 - val_iou_thresholded: 0.7881
# Epoch 69/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0886 - iou: 0.5339 - iou_thresholded: 0.7724 - val_loss: 0.0886 - val_iou: 0.5245 - val_iou_thresholded: 0.7918
# Epoch 70/100
# 22/22 [==============================] - 16s 708ms/step - loss: 0.0815 - iou: 0.5503 - iou_thresholded: 0.7951 - val_loss: 0.0851 - val_iou: 0.5387 - val_iou_thresholded: 0.8004
# Epoch 71/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.0826 - iou: 0.5523 - iou_thresholded: 0.7931 - val_loss: 0.1113 - val_iou: 0.4653 - val_iou_thresholded: 0.7498
# Epoch 72/100
# 22/22 [==============================] - 16s 711ms/step - loss: 0.0819 - iou: 0.5518 - iou_thresholded: 0.7941 - val_loss: 0.0852 - val_iou: 0.5402 - val_iou_thresholded: 0.7979
# Epoch 73/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.0777 - iou: 0.5656 - iou_thresholded: 0.8076 - val_loss: 0.0778 - val_iou: 0.5622 - val_iou_thresholded: 0.8194
# Epoch 74/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0777 - iou: 0.5684 - iou_thresholded: 0.8087 - val_loss: 0.0858 - val_iou: 0.5423 - val_iou_thresholded: 0.7924
# Epoch 75/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.0761 - iou: 0.5715 - iou_thresholded: 0.8113 - val_loss: 0.0933 - val_iou: 0.5133 - val_iou_thresholded: 0.7946
# Epoch 76/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.0785 - iou: 0.5692 - iou_thresholded: 0.8050 - val_loss: 0.0902 - val_iou: 0.5325 - val_iou_thresholded: 0.7757
# Epoch 77/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.0764 - iou: 0.5765 - iou_thresholded: 0.8110 - val_loss: 0.0871 - val_iou: 0.5405 - val_iou_thresholded: 0.7914
# Epoch 78/100
# 22/22 [==============================] - 16s 710ms/step - loss: 0.0763 - iou: 0.5786 - iou_thresholded: 0.8103 - val_loss: 0.0864 - val_iou: 0.5368 - val_iou_thresholded: 0.8007
# Epoch 79/100
# 22/22 [==============================] - 16s 720ms/step - loss: 0.0746 - iou: 0.5839 - iou_thresholded: 0.8150 - val_loss: 0.0866 - val_iou: 0.5381 - val_iou_thresholded: 0.7978
# Epoch 80/100
# 22/22 [==============================] - 16s 714ms/step - loss: 0.0735 - iou: 0.5874 - iou_thresholded: 0.8186 - val_loss: 0.0746 - val_iou: 0.5767 - val_iou_thresholded: 0.8302
# Epoch 81/100
# 22/22 [==============================] - 16s 708ms/step - loss: 0.0716 - iou: 0.5949 - iou_thresholded: 0.8250 - val_loss: 0.0802 - val_iou: 0.5652 - val_iou_thresholded: 0.8076
# Epoch 82/100
# 22/22 [==============================] - 16s 711ms/step - loss: 0.0712 - iou: 0.5960 - iou_thresholded: 0.8241 - val_loss: 0.0751 - val_iou: 0.5797 - val_iou_thresholded: 0.8269
# Epoch 83/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.0712 - iou: 0.5987 - iou_thresholded: 0.8236 - val_loss: 0.0764 - val_iou: 0.5804 - val_iou_thresholded: 0.8172
# Epoch 84/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0703 - iou: 0.6011 - iou_thresholded: 0.8242 - val_loss: 0.0747 - val_iou: 0.5889 - val_iou_thresholded: 0.8212
# Epoch 85/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.0708 - iou: 0.6017 - iou_thresholded: 0.8226 - val_loss: 0.0804 - val_iou: 0.5691 - val_iou_thresholded: 0.8042
# Epoch 86/100
# 22/22 [==============================] - 16s 708ms/step - loss: 0.0716 - iou: 0.6034 - iou_thresholded: 0.8211 - val_loss: 0.0799 - val_iou: 0.5709 - val_iou_thresholded: 0.8078
# Epoch 87/100
# 22/22 [==============================] - 16s 707ms/step - loss: 0.0689 - iou: 0.6122 - iou_thresholded: 0.8308 - val_loss: 0.0773 - val_iou: 0.5835 - val_iou_thresholded: 0.8103
# Epoch 88/100
# 22/22 [==============================] - 16s 706ms/step - loss: 0.0679 - iou: 0.6137 - iou_thresholded: 0.8308 - val_loss: 0.0737 - val_iou: 0.5869 - val_iou_thresholded: 0.8288
# Epoch 89/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0686 - iou: 0.6136 - iou_thresholded: 0.8271 - val_loss: 0.0850 - val_iou: 0.5588 - val_iou_thresholded: 0.7908
# Epoch 90/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.0720 - iou: 0.6048 - iou_thresholded: 0.8132 - val_loss: 0.0740 - val_iou: 0.6013 - val_iou_thresholded: 0.8171
# Epoch 91/100
# 22/22 [==============================] - 16s 708ms/step - loss: 0.0686 - iou: 0.6147 - iou_thresholded: 0.8243 - val_loss: 0.0690 - val_iou: 0.6157 - val_iou_thresholded: 0.8368
# Epoch 92/100
# 22/22 [==============================] - 15s 705ms/step - loss: 0.0669 - iou: 0.6223 - iou_thresholded: 0.8310 - val_loss: 0.0851 - val_iou: 0.5658 - val_iou_thresholded: 0.7833
# Epoch 93/100
# 22/22 [==============================] - 16s 709ms/step - loss: 0.0663 - iou: 0.6244 - iou_thresholded: 0.8312 - val_loss: 0.0671 - val_iou: 0.6263 - val_iou_thresholded: 0.8429
# Epoch 94/100
# 22/22 [==============================] - 15s 704ms/step - loss: 0.0665 - iou: 0.6253 - iou_thresholded: 0.8294 - val_loss: 0.0685 - val_iou: 0.6172 - val_iou_thresholded: 0.8362
# Epoch 95/100
# 22/22 [==============================] - 16s 711ms/step - loss: 0.0671 - iou: 0.6261 - iou_thresholded: 0.8279 - val_loss: 0.0774 - val_iou: 0.5870 - val_iou_thresholded: 0.8082
# Epoch 96/100
# 22/22 [==============================] - 15s 705ms/step - loss: 0.0639 - iou: 0.6355 - iou_thresholded: 0.8391 - val_loss: 0.0732 - val_iou: 0.6013 - val_iou_thresholded: 0.8199
# Epoch 97/100
# 22/22 [==============================] - 16s 721ms/step - loss: 0.0632 - iou: 0.6375 - iou_thresholded: 0.8395 - val_loss: 0.0704 - val_iou: 0.6168 - val_iou_thresholded: 0.8254
# Epoch 98/100
# 22/22 [==============================] - 15s 703ms/step - loss: 0.0624 - iou: 0.6431 - iou_thresholded: 0.8440 - val_loss: 0.0699 - val_iou: 0.6182 - val_iou_thresholded: 0.8271
# Epoch 99/100
# 22/22 [==============================] - 16s 714ms/step - loss: 0.0614 - iou: 0.6440 - iou_thresholded: 0.8426 - val_loss: 0.0658 - val_iou: 0.6377 - val_iou_thresholded: 0.8427
# Epoch 100/100
# 22/22 [==============================] - 15s 702ms/step - loss: 0.0635 - iou: 0.6414 - iou_thresholded: 0.8367 - val_loss: 0.0683 - val_iou: 0.6254 - val_iou_thresholded: 0.8327
# #############################

# %%
def create_Umodel():
    import keras.optimizers
    from keras_unet.metrics import iou, iou_thresholded
    from keras_unet.losses import jaccard_distance
    model = custom_unet(
                    input_shape=(512, 512, 1),
                    use_batch_norm=False,
                    num_classes=1,
                    filters=32,
                    dropout=0.5,
                    output_activation='sigmoid')

# %%
def wtrain(number):
    from keras import regularizers
    from keras.layers import Dense
    from keras.callbacks import EarlyStopping
    from keras.preprocessing.image import ImageDataGenerator
    from keras_unet.utils import plot_segm_history, plot_imgs
    import cv2
    from PIL import Image
    from skimage.filters import threshold_otsu
    from keras.preprocessing.image import ImageDataGenerator
    al = 1
    for k in range(number):
        # create a new model with the same architecture as the original model
        new_model = create_Umodel()
        path = '/raid/mpsych/RISTERLAB/kiran/flyem/K_Experiments/models/Unet'
        # load the previously saved weights into the new model
        new_model.load_weights(f'{path}/new_Umodel{al}.h5')
        print (f'loaded model : new_Umodel{al}.h5')
        # compile the new model        
        opt = keras.optimizer_v1.Adam(lr=0.01)
        # compile the new model
        new_model.compile(optimizer = 'Adam',    
                          loss='binary_crossentropy', 
                          metrics=[iou, iou_thresholded])
        # Early stopping
        early_stopping = EarlyStopping(monitor='val_loss', patience=10)
        # Training with early stopping
        history = model.fit(X_train,
                            y_train,
                            batch_size=60,
                            epochs=700,
                            validation_data=(X_val, y_val),
                            callbacks=[early_stopping])


        bl = (al+1)
        # save the updated weights of the new model
        new_model.save_weights(f'{path}/new_Umodel{bl}.h5')
        
        print (f'saved model : new_Umodel{bl}.h5')
        # Make predictions and apply thresholding
        y_pred = new_model.predict(X_test)



#         for i in range(5):
#             binary_mask = y_pred[i]
#             z = images_name[i]
#             threshold = 0.2
#             binary_mask = (binary_mask[i] > threshold).astype(np.uint8)
#             # Convert the binary_mask variable to a 2D array
#             binary_mask_2d = binary_mask.squeeze()
#             Convert the binary_mask variable to uint8 format
#             binary_mask_uint8 = (binary_mask_2d * 255).astype(np.uint8)
#             save_path = os.path.join(dir_path, z) 
#             binary_mask_new = np.array(binary_mask_uint8)
#             mh.imsave(save_path, binary_mask_new)
            
        threshold = 0.2
        y_pred_binary = (y_pred[i] > threshold).astype(np.uint8)
        plot_segm_history(history)   
        plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=10
        al += 1
        print ('completed iteration number',k,'The value of al is ',al)
        print ('#############################')
        print()
        print()
        print()

# %%
wtrain(5)
